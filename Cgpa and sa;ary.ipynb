# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayeshaparmar05/Ai-assignment/blob/main/Cgpa%20and%20sa%3Bary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib .pyplot as pl

# %%
x=[20,30,40,50]
y=[2,3,4,5]
pl.plot(x,y,"o-b")
pl.xlabel('salary')
pl.ylabel('Cgpa')
pl.title('CGPA vs Salary')
pl.show()
